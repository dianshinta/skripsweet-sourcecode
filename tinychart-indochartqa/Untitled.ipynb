# %%
# %load_ext tensorboard
# %tensorboard --logdir /workspace/checkpoints/TinyChart-3B/runs
# Out:
#       <iframe id="tensorboard-frame-31b1a10b65d32e32" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-31b1a10b65d32e32");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
